# %% [markdown]
# ## 1. Import all needed Libraries/Module

# %%
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
import numpy

# %% [markdown]
# ## 2. Read data, and then do some explanatory data analysis

# %%
data=pd.read_csv('./data/clean_scaler.csv',header=0,index_col=0)
data
# Out:
#           DC024     DC025     DC205     DC206     DC207     DC208     DC209
# 0     -1.366487  1.064899  0.167348  0.203834 -0.482752  0.425157 -1.150516  \
# 1     -1.366487  1.064899  2.642485  0.203834 -0.482752  0.425157 -1.150516
# 2     -1.366487  1.064899 -0.492688  0.203834 -0.482752  0.425157  0.869175
# 3     -1.366487  1.064899 -0.492688  0.203834 -0.482752 -2.352070 -1.150516
# 4     -1.366487  1.064899 -0.492688  0.203834 -0.482752  0.425157  0.869175
# ...         ...       ...       ...       ...       ...       ...       ...
# 64791 -1.176806  1.064899  2.642485  0.203834 -0.482752  0.425157 -1.150516
# 64792 -0.476104  1.064899  0.167348  0.203834 -0.482752  0.126948 -1.150516
# 64793  1.387145  1.064899  2.642485 -4.905945 -0.482752 -2.352070 -1.150516
# 64794  1.007235  1.064899  2.233041  0.203834 -0.482752  0.425157 -1.150516
# 64795 -0.306508 -0.939056  0.332358 -4.905945 -0.482752  0.425157 -1.150516
#
#           DC210     DC211     DC212  ...    DC237f     DC241     DC242
# 0     -0.695990 -1.773233 -0.390844  ... -0.466686 -0.361838 -2.406758  \
# 1     -0.695990  0.563942 -0.390844  ... -0.466686 -0.361838 -2.406758
# 2      1.436802  0.563942 -0.390844  ... -0.466686 -0.361838 -2.406758
# 3     -0.695990  0.563942 -0.390844  ... -0.466686  1.838364  0.415497
# 4     -0.695990 -1.773233 -0.390844  ... -0.466686 -0.361838 -2.406758
# ...         ...       ...       ...  ...       ...       ...       ...
# 64791 -0.695990 -1.773233 -0.390844  ... -0.466686  4.038566  0.415497
# 64792  1.436802  0.563942 -0.390844  ...  1.884588 -0.361838  0.415497
# 64793 -0.695990 -1.773233 -0.390844  ... -0.202581  4.038566  0.415497
# 64794 -0.695990  0.563942 -0.390844  ...  1.884588 -0.361838  0.415497
# 64795 -0.695990 -0.245398 -0.390844  ...  1.884588 -0.361838  0.415497
#
#           DC244     DC246     DC252    DC270a     DC109    DC142a  DC201
# 0     -0.760198 -0.782016  0.645898 -1.183663 -0.364421 -0.248383      0
# 1      1.315446  1.278746 -0.168533 -0.487116  1.615413 -0.138651      0
# 2      1.315446  1.278746 -0.982963  0.905978 -0.468623 -0.083785      0
# 3      1.315446 -0.782016 -0.168533 -1.183663 -0.468623  0.025947      0
# 4     -0.760198  1.278746 -0.982963 -0.487116 -0.468623 -0.193517      0
# ...         ...       ...       ...       ...       ...       ...    ...
# 64791 -0.760198  0.917219 -0.025654 -1.183663  3.333839 -0.426263      1
# 64792  1.315446  1.278746 -0.168533  0.209431 -0.364421 -0.345892      1
# 64793  1.082301 -0.782016 -0.168533 -1.183663  3.699449 -0.598532      1
# 64794  1.315446 -0.270670 -0.168533 -1.183663  1.873974 -0.347224      1
# 64795 -0.760198 -0.782016 -0.700934 -1.183663  0.573395 -0.595260      1
#
# [64796 rows x 39 columns]

# %%
# gather information about data attribute
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 64796 entries, 0 to 64795
# Data columns (total 39 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DC024   64796 non-null  float64
#  1   DC025   64796 non-null  float64
#  2   DC205   64796 non-null  float64
#  3   DC206   64796 non-null  float64
#  4   DC207   64796 non-null  float64
#  5   DC208   64796 non-null  float64
#  6   DC209   64796 non-null  float64
#  7   DC210   64796 non-null  float64
#  8   DC211   64796 non-null  float64
#  9   DC212   64796 non-null  float64
#  10  DC213   64796 non-null  float64
#  11  DC214   64796 non-null  float64
#  12  DC215   64796 non-null  float64
#  13  DC216   64796 non-null  float64
#  14  DC217   64796 non-null  float64
#  15  DC219   64796 non-null  float64
#  16  DC220   64796 non-null  float64
#  17  DC226   64796 non-null  float64
#  18  DC230a  64796 non-null  float64
#  19  DC230b  64796 non-null  float64
#  20  DC232   64796 non-null  float64
#  21  DC232b  64796 non-null  float64
#  22  DC235   64796 non-null  float64
#  23  DC237   64796 non-null  float64
#  24  DC237a  64796 non-null  float64
#  25  DC237b  64796 non-null  float64
#  26  DC237c  64796 non-null  float64
#  27  DC237d  64796 non-null  float64
#  28  DC237e  64796 non-null  float64
#  29  DC237f  64796 non-null  float64
#  30  DC241   64796 non-null  float64
#  31  DC242   64796 non-null  float64
#  32  DC244   64796 non-null  float64
#  33  DC246   64796 non-null  float64
#  34  DC252   64796 non-null  float64
#  35  DC270a  64796 non-null  float64
#  36  DC109   64796 non-null  float64
#  37  DC142a  64796 non-null  float64
#  38  DC201   64796 non-null  int64
# dtypes: float64(38), int64(1)
# memory usage: 19.8 MB

# %% [markdown]
# Dari data di atas, dapat dilihat bahwa semua data bertipe data flloat/integer, dan label bertipe data string.

# %% [markdown]
# ## Cari informasi apakah ada data yang bernilai null/kosong

# %%
data.isnull().sum()
# Out:
# DC024     0
# DC025     0
# DC205     0
# DC206     0
# DC207     0
# DC208     0
# DC209     0
# DC210     0
# DC211     0
# DC212     0
# DC213     0
# DC214     0
# DC215     0
# DC216     0
# DC217     0
# DC219     0
# DC220     0
# DC226     0
# DC230a    0
# DC230b    0
# DC232     0
# DC232b    0
# DC235     0
# DC237     0
# DC237a    0
# DC237b    0
# DC237c    0
# DC237d    0
# DC237e    0
# DC237f    0
# DC241     0
# DC242     0
# DC244     0
# DC246     0
# DC252     0
# DC270a    0
# DC109     0
# DC142a    0
# DC201     0
# dtype: int64

# %% [markdown]
# ## Cari korelasi tiap atribut dengan pandas corr

# %%
#Split dataset menjadi training dan testing
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(data.drop('DC201',axis=1),data['DC201'],test_size=0.3)
input_shape=(x_train.shape)
input_shape
# Out:
# (45357, 38)

# %%
from keras import backend as K

def recall_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    possible_positives = K.sum(K.round(K.clip(y_true, 0, 1)))
    recall = true_positives / (possible_positives + K.epsilon())
    return recall

def precision_m(y_true, y_pred):
    true_positives = K.sum(K.round(K.clip(y_true * y_pred, 0, 1)))
    predicted_positives = K.sum(K.round(K.clip(y_pred, 0, 1)))
    precision = true_positives / (predicted_positives + K.epsilon())
    return precision

def f1_m(y_true, y_pred):
    precision = precision_m(y_true, y_pred)
    recall = recall_m(y_true, y_pred)
    return 2*((precision*recall)/(precision+recall+K.epsilon()))

# %% [markdown]
# ### Create Model

# %%
import tensorflow as tf

# %%
model=tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=32,kernel_size=3,input_shape=(38,1),activation='relu'),
    tf.keras.layers.Conv1D(filters=32,kernel_size=3,activation='relu'),
    tf.keras.layers.Conv1D(filters=32,kernel_size=3,activation='relu'),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.MaxPool1D(2,2),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',f1_m])

# Print the model summary
print(model.summary())
# Out:
# Model: "sequential_15"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_33 (Conv1D)          (None, 36, 32)            128
#
#  conv1d_34 (Conv1D)          (None, 34, 32)            3104
#
#  conv1d_35 (Conv1D)          (None, 32, 32)            3104
#
#  dropout_8 (Dropout)         (None, 32, 32)            0
#
#  max_pooling1d_14 (MaxPoolin  (None, 16, 32)           0
#  g1D)
#
#  flatten_11 (Flatten)        (None, 512)               0
#
#  dense_30 (Dense)            (None, 512)               262656
#
#  dense_31 (Dense)            (None, 100)               51300
#
#  dense_32 (Dense)            (None, 1)                 101
#
# =================================================================
# Total params: 320,393
# Trainable params: 320,393
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
from keras.models import Sequential
from keras.layers import Conv1D, MaxPooling1D, Flatten, Dense, Dropout

# Define the input shape
input_shape = (11, 1)  # 38 attributes, 1 feature

# Define the model architecture
model=tf.keras.models.Sequential([
    tf.keras.layers.Conv1D(filters=64,kernel_size=3,input_shape=(38,1),activation='relu'),
    tf.keras.layers.Conv1D(filters=64,kernel_size=3,activation='relu'),
    tf.keras.layers.MaxPool1D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv1D(filters=128,kernel_size=3,activation='relu'),
    tf.keras.layers.Conv1D(filters=128,kernel_size=3,activation='relu'),
    tf.keras.layers.MaxPool1D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Conv1D(filters=256,kernel_size=3,activation='relu'),
    tf.keras.layers.Conv1D(filters=256,kernel_size=3,activation='relu'),
    tf.keras.layers.MaxPool1D(2,2),
    tf.keras.layers.Dropout(0.25),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(512,activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(1,activation='sigmoid')])

# Compile the model
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy',f1_m])

# Print the model summary
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d (Conv1D)             (None, 36, 64)            256
#
#  conv1d_1 (Conv1D)           (None, 34, 64)            12352
#
#  max_pooling1d (MaxPooling1D  (None, 17, 64)           0
#  )
#
#  dropout (Dropout)           (None, 17, 64)            0
#
#  conv1d_2 (Conv1D)           (None, 15, 128)           24704
#
#  conv1d_3 (Conv1D)           (None, 13, 128)           49280
#
#  max_pooling1d_1 (MaxPooling  (None, 6, 128)           0
#  1D)
#
#  dropout_1 (Dropout)         (None, 6, 128)            0
#
#  conv1d_4 (Conv1D)           (None, 4, 256)            98560
#
#  conv1d_5 (Conv1D)           (None, 2, 256)            196864
#
#  max_pooling1d_2 (MaxPooling  (None, 1, 256)           0
#  1D)
#
#  dropout_2 (Dropout)         (None, 1, 256)            0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 512)               131584
#
#  dropout_3 (Dropout)         (None, 512)               0
#
#  dense_1 (Dense)             (None, 1)                 513
#
# =================================================================
# Total params: 514,113
# Trainable params: 514,113
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
history=model.fit(x_train,y_train,epochs=10,batch_size=32,validation_split=0.2)
# Out:
# Epoch 1/10
# 1134/1134 [==============================] - 15s 12ms/step - loss: 0.4315 - accuracy: 0.7985 - f1_m: 0.8004 - val_loss: 0.3927 - val_accuracy: 0.8232 - val_f1_m: 0.8167
# Epoch 2/10
# 1134/1134 [==============================] - 12s 10ms/step - loss: 0.3598 - accuracy: 0.8362 - f1_m: 0.8344 - val_loss: 0.3068 - val_accuracy: 0.8688 - val_f1_m: 0.8666
# Epoch 3/10
# 1134/1134 [==============================] - 11s 9ms/step - loss: 0.3041 - accuracy: 0.8617 - f1_m: 0.8573 - val_loss: 0.2768 - val_accuracy: 0.8726 - val_f1_m: 0.8748
# Epoch 4/10
# 1134/1134 [==============================] - 10s 9ms/step - loss: 0.2741 - accuracy: 0.8765 - f1_m: 0.8721 - val_loss: 0.2661 - val_accuracy: 0.8761 - val_f1_m: 0.8783
# Epoch 5/10
# 1134/1134 [==============================] - 10s 9ms/step - loss: 0.2476 - accuracy: 0.8890 - f1_m: 0.8846 - val_loss: 0.2411 - val_accuracy: 0.8911 - val_f1_m: 0.8891
# Epoch 6/10
# 1134/1134 [==============================] - 10s 9ms/step - loss: 0.2293 - accuracy: 0.8981 - f1_m: 0.8950 - val_loss: 0.2308 - val_accuracy: 0.8955 - val_f1_m: 0.8947
# Epoch 7/10
# 1134/1134 [==============================] - 10s 9ms/step - loss: 0.2112 - accuracy: 0.9072 - f1_m: 0.9044 - val_loss: 0.2249 - val_accuracy: 0.9013 - val_f1_m: 0.9005
# Epoch 8/10
# 1134/1134 [==============================] - 10s 9ms/step - loss: 0.1925 - accuracy: 0.9157 - f1_m: 0.9125 - val_loss: 0.2036 - val_accuracy: 0.9109 - val_f1_m: 0.9092
# Epoch 9/10
# 1134/1134 [==============================] - 11s 9ms/step - loss: 0.1807 - accuracy: 0.9224 - f1_m: 0.9198 - val_loss: 0.2038 - val_accuracy: 0.9090 - val_f1_m: 0.9069
# Epoch 10/10
# 1134/1134 [==============================] - 10s 9ms/step - loss: 0.1643 - accuracy: 0.9298 - f1_m: 0.9276 - val_loss: 0.1985 - val_accuracy: 0.9159 - val_f1_m: 0.9141

# %%
model.evaluate(x_test,y_test)
# Out:
# 608/608 [==============================] - 4s 7ms/step - loss: 0.1895 - accuracy: 0.9197 - f1_m: 0.9185
# [0.18947093188762665, 0.9196975231170654, 0.9185103178024292]

# %%
#Menampilkan grafik akurasi
import matplotlib.pyplot as plt

def plot_graphs(history, metric):
  plt.plot(history.history[metric])
  plt.plot(history.history['val_'+metric], '')
  plt.xlabel("Epochs")
  plt.ylabel(metric)
  plt.title(f'Grafik {metric}')
  plt.legend([metric, 'val_'+metric])
  
plot_graphs(history,'f1_m')

# %%
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
clf = svm.SVC(verbose=True)
clf.fit(x_train, y_train)
# melakukan prediksi menggunakan data testing
y_pred = clf.predict(x_test)

# menghitung akurasi
acc = accuracy_score(y_test, y_pred)

print('Accuracy:', acc)
# Out:
# [LibSVM]Accuracy: 0.8887288440763413
